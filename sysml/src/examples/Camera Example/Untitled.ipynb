# %%
package PictureTaking {
	part def <'lil name'> Exposure;
	
	action def Focus { out xrsl: Exposure; }
	action def Shoot { in xsf: Exposure; }	
		
	action takePicture {		
		action focus: Focus[1];
		flow of Exposure from focus.xrsl to shoot.xsf;
		action shoot: Shoot[1];
	}
}

part def Camera {
	private import PictureTaking::*;
	
	perform action takePicture[*] :> PictureTaking::takePicture;
	
	part focusingSubsystem {
		perform takePicture.focus;
	}
	
	part imagingSubsystem {
		perform takePicture.shoot;
	}
}

/*this is a comment*/
# Out:
# Package PictureTaking (7ab46e34-c460-432c-8853-5657a935495d)
# PartDefinition Camera (b154390f-4234-43bb-af18-96c6bec5a59f)
# Comment (d7dcb413-7ede-43ed-9f49-7d40d91131ec)

# %%
%viz Camera
